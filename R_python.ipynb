# %% [markdown]
# <a href="https://colab.research.google.com/github/joelrodrigue2016/FAU/blob/main/R_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using R and Python together with google colab

# %% [markdown]
# Python

# %%
import numpy as np
from matplotlib import pyplot as plt
a = np.linspace(-5,5,500)
b = np.cos(a)
plt.plot(a,b,'green')
plt.show()

# %% [markdown]
# R example

# %%
# activate R magic
# %load_ext rpy2.ipython

# %%
# %%R
#
# x <- seq(-5,5,0.005)
# y<- cos(x)
# plot(x, y,col = 'green')
